# %%
import pandas as pd

# %%
data={
    'Name':['Neha','Satya','Deepthi'],
    'Age':[12,18,19],
    'Houses':['Red','White','Yellow']
}
df=pd.DataFrame(data)
df
# Out:
#       Name  Age  Houses
# 0     Neha   12     Red
# 1    Satya   18   White
# 2  Deepthi   19  Yellow

# %%
df.shape
# Out:
# (3, 3)

# %%
df.size
# Out:
# 9

# %%
df.ndim
# Out:
# 2

# %%
df.dtypes
# Out:
# Name      object
# Age        int64
# Houses    object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   Houses  3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes

# %%
df.memory_usage()
# Out:
# Index     132
# Name       24
# Age        24
# Houses     24
# dtype: int64

# %%
df.describe()
# Out:
#              Age
# count   3.000000
# mean   16.333333
# std     3.785939
# min    12.000000
# 25%    15.000000
# 50%    18.000000
# 75%    18.500000
# max    19.000000

# %%
df['Age']
# Out:
# 0    12
# 1    18
# 2    19
# Name: Age, dtype: int64

# %%
df['Name']
# Out:
# 0       Neha
# 1      Satya
# 2    Deepthi
# Name: Name, dtype: object

# %%
df.drop('Age',axis=1)
# Out:
#       Name  Houses
# 0     Neha     Red
# 1    Satya   White
# 2  Deepthi  Yellow

# %%
df.rename(columns={'Houses':'Home'},inplace=True)
print(df)
# Out:
#       Name  Age    Home
# 0     Neha   12     Red
# 1    Satya   18   White
# 2  Deepthi   19  Yellow

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   Houses  3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes

# %%
data={
    'Name':['Neha','Satya','Deepthi'],
    'Age':[12,18,19],
    'Houses':['Red','White','Yellow'],
    'Subject':['science','maths','physics']
}
df=pd.DataFrame(data)
df
# Out:
#       Name  Age  Houses  Subject
# 0     Neha   12     Red  science
# 1    Satya   18   White    maths
# 2  Deepthi   19  Yellow  physics

# %%
df.drop('Subject',axis=1)
# Out:
#       Name  Age  Houses
# 0     Neha   12     Red
# 1    Satya   18   White
# 2  Deepthi   19  Yellow

# %%
df.isnull()
# Out:
#     Name    Age  Houses  Subject
# 0  False  False   False    False
# 1  False  False   False    False
# 2  False  False   False    False

# %%
df.dropna()
# Out:
#       Name  Age  Houses  Subject
# 0     Neha   12     Red  science
# 1    Satya   18   White    maths
# 2  Deepthi   19  Yellow  physics

# %%
df.shape
# Out:
# (3, 4)

# %%
df.describe()
# Out:
#              Age
# count   3.000000
# mean   16.333333
# std     3.785939
# min    12.000000
# 25%    15.000000
# 50%    18.000000
# 75%    18.500000
# max    19.000000

# %%
df.memory_usage()
# Out:
# Index      132
# Name        24
# Age         24
# Houses      24
# Subject     24
# dtype: int64

# %%
df.size
# Out:
# 12
